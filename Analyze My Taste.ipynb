# %%
import pandas as pd
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv("./train csv/train.csv")

# %%
sns.countplot(x="isLiked", data=df)

# %%
df.columns
# Out:
# Index(['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#        'type', 'id', 'uri', 'track_href', 'analysis_url', 'duration_ms',
#        'time_signature', 'name', 'isLiked'],
#       dtype='object')

# %%
sns.scatterplot(x="danceability", y="energy", hue="isLiked", data=df)

# %%
#danceability
df.corr().sort_values('danceability')
# Out:
#                   danceability    energy       key  loudness      mode  \
# duration_ms          -0.414122  0.083088  0.041093 -0.064733 -0.176662
# acousticness         -0.191689 -0.734900  0.085427 -0.572160  0.256130
# isLiked              -0.167484  0.279284  0.131237  0.198474 -0.031281
# liveness             -0.100476  0.172242  0.117680 -0.040790 -0.299171
# mode                 -0.049318 -0.206846 -0.124915 -0.151121  1.000000
# energy               -0.047633  1.000000 -0.116158  0.787596 -0.206846
# tempo                -0.033385  0.204119  0.002456  0.249006 -0.047943
# loudness              0.016551  0.787596 -0.064883  1.000000 -0.151121
# instrumentalness      0.029609 -0.293433 -0.047093 -0.450638  0.023805
# speechiness           0.030526  0.102821 -0.076824  0.043257 -0.010540
# time_signature        0.065898  0.095649 -0.028121  0.158850 -0.191920
# key                   0.079833 -0.116158  1.000000 -0.064883 -0.124915
# ...

# %%
#danceability
df.corr().sort_values('energy')
# Out:
#                   danceability    energy       key  loudness      mode  \
# acousticness         -0.191689 -0.734900  0.085427 -0.572160  0.256130
# instrumentalness      0.029609 -0.293433 -0.047093 -0.450638  0.023805
# mode                 -0.049318 -0.206846 -0.124915 -0.151121  1.000000
# key                   0.079833 -0.116158  1.000000 -0.064883 -0.124915
# danceability          1.000000 -0.047633  0.079833  0.016551 -0.049318
# duration_ms          -0.414122  0.083088  0.041093 -0.064733 -0.176662
# time_signature        0.065898  0.095649 -0.028121  0.158850 -0.191920
# speechiness           0.030526  0.102821 -0.076824  0.043257 -0.010540
# liveness             -0.100476  0.172242  0.117680 -0.040790 -0.299171
# tempo                -0.033385  0.204119  0.002456  0.249006 -0.047943
# isLiked              -0.167484  0.279284  0.131237  0.198474 -0.031281
# valence               0.302322  0.291505 -0.027556  0.135402  0.155284
# ...

# %%
sns.scatterplot(x="energy", y="acousticness", data=df)

# %%
sns.scatterplot(x="energy", y="acousticness", hue="isLiked", data=df)

# %%
sns.scatterplot(x="energy", y="loudness", data=df)

# %%
sns.scatterplot(x="acousticness", y="loudness", data=df)

# %% [markdown]
# energy similar to acousticness and loudness, remove energy?

# %% [markdown]
# The rest of the features are not really correlated.
